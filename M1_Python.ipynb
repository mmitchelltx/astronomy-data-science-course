# %% [markdown]
# <a href="https://colab.research.google.com/github/mmitchelltx/astronomy-data-science-course/blob/main/M1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python
# ---

# %% [markdown]
# ## 1) Comments
# * Useful when you want to document / review the code.
# * Comments are not executed as code.
# * We create comments in python using #.

# %%
# This is a regular single line comment

# %%
# Use ctl + / to comment or uncomment code you select.

# %% [markdown]
# ## 2) Data Type - String

# %%
# Use single quotes to create a string
'this is a string, 513'
'this is also a string'
# Out:
# 'this is also a string'

# %%
# use print command to display both strings
print('this is a string, 513')
print('this is also a string')
# Out:
# this is a string, 513
# this is also a string

# %%
# type command displays the type of data
type('is this a string')
# Out:
# str

# %%
# you can also combine commands
print(type('is this a string'))
# Out:
# <class 'str'>

# %%
# double quotes can also give you a string
"This is also a string!"
# Out:
# 'This is also a string!'

# %%
len('this is a string, len gives us a count of the charaters')
# Out:
# 55

# %%
# triple quotes can also be stings, these are mostly used for docstrings to define functions in python
#these can be used for single or multiple lines for example
"""
this is a line of code
this is a line of code
"""
# Out:
# '\nthis is a line of code\nthis is a line of code\n'

# %% [markdown]
# ## 3) Data Type - Variables and Constants

# %%
# to store data that changes with time, use variables
age = 35 # variables in python are always written with lowercase letters

# %%
# display type of data in variable
type(35)
# Out:
# int

# %%
# to store something that can never change with time use a constant
# create constants using UPPER CASE letters
PI = 3.14 # pi value
G = 9.81 # constant for gravity

# %%
# print variable or contant
print(PI)
print(G)
# Out:
# 3.14
# 9.81

# %% [markdown]
# ## 4) Data Type - Numerical
# * Integers
# * Floats
# * Complex Numbers

# %%
# fntegers is a whole number, can be negative or positive
print(type(7))
print(type(49))
print(type(-7))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# floats are can be any number with a .
print(type(7.0))
print(type(-87.938473))
print(type(97.838292))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# complex numbers will have an inclusion of j for imaginary part of complex number
print(type(3j))
print(type(3j+4))
# Out:
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# ## 5) Data Type - Conversions
# * You can convert a string to numerical type
# * You can convert float to int
# * You are allowed to convert a data type if it allowed by python

# %%
type('7') # 7 is type str
# Out:
# str

# %%
int('7') # converts '7' str to 7 int
# Out:
# 7

# %%
float('7') # converts to float 7.0
# Out:
# 7.0

# %%
# convert to float
int_example = 3
print(int_example)
print()
float_output = float(int_example)
print(float_output)
# Out:
# 3
#
# 3.0
